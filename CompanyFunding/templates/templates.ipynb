# %%
# %%file data.html
# {% block content %}
# </form>
#   <table id="data" class="table table-striped">
#     <thead>
#       <tr>
#         <th>permalink</th>
#         <th>company</th>
#         <th>numEmps</th>
#         <th>category</th>
#         <th>city</th>
#         <th>state</th>
#         <th>fundedDate</th>
#         <th>raisedAmt</th>
#         <th>raisedCurrency</th>
#         <th>roundx</th>
#         <th>id</th>
#       </tr>
#     </thead>
#     <tbody>
#       {% for row in tbl %}
#        <tr>
#           <td><a href="{{ row.id }}">{{ row.permalink }}</a></td>
#           <td><a href="{{ row.id }}">{{ row.company }}</a></td>
#           <td><a href="{{ row.id }}">{{ row.numEmps }}</a></td>
#           <td><a href="{{ row.id }}">{{ row.category }}</a></td>
#           <td><a href="{{ row.id }}">{{ row.city }}</a></td>
#           <td><a href="{{ row.id }}">{{ row.state }}</a></td>
#           <td><a href="{{ row.id }}">{{ row.fundedDate }}</a></td>
#           <td><a href="{{ row.id }}">{{ row.raisedAmt }}</a></td>
#           <td><a href="{{ row.id }}">{{ row.raisedCurrency }}</a></td>
#           <td><a href="{{ row.id }}">{{ row.roundx }}</a></td>
#           <td><a href="{{ row.id }}">{{ row.id }}</a></td>
#        </tr>
#       {% endfor %}
#     </tbody>
#   </table>
# {% endblock %}
# Out:
# Overwriting data.html

# %%
# %%file create.html
#
# {% block content %}
#     <h1 style="width: 100%">{% block title %} Add a record {% endblock %}</h1>
#     <form method="post">
#         <p>
#             <label for="permalink">permalink</label>
#             <input type="text" name="permalink"
#                    placeholder="permalink">
#             </input>
#         </p>
#
#         <p>
#             <label for="company">company</label>
#             <input type="text" name="company"
#                    placeholder="company">
#             </input>
#         </p>
#
#         <p>
#             <label for="numEmps">numEmps</label>
#             <input type="numEmps" name="numEmps"
#                    placeholder="numEmps">
#             </input>
#         </p>
#
#             <p>
#             <label for="category">category</label>
#             <input type="category" name="category"
#                    placeholder="category">
#             </input>
#             </p>
#             <p>
#             <label for="city">city</label>
#             <input type="city" name="city"
#                    placeholder="city">
#             </input>
#             </p>
#
#
#             <p>
#             <label for="state">state</label>
#             <input type="state" name="state"
#                    placeholder="state">
#             </input>
#             </p>
#
#             <p>
#             <label for="fundedDate">fundedDate</label>
#             <input type="fundedDate" name="fundedDate"
#                    placeholder="fundedDate">
#             </input>
#             </p>
#
#             <p>
#             <label for="raisedAmt">raisedAmt</label>
#             <input type="raisedAmt" name="raisedAmt"
#                    placeholder="raisedAmt">
#             </input>
#             </p>
#
#               <p>
#             <label for="raisedCurrency">raisedCurrency</label>
#             <input type="raisedCurrency" name="raisedCurrency"
#                    placeholder="raisedCurrency">
#             </input>
#             </p>
#
#             <p>
#             <label for="roundx">roundx</label>
#             <input type="roundx" name="roundx"
#                    placeholder="roundx">
#             </input>
#             </p>
#
#         <p>
#             <button type="submit">Submit</button>
#         </p>
#     </form>
# {% endblock %}
# Out:
# Overwriting create.html

# %%
# %%file delete.html
# <form action='' method="post">
#     Click YES to confirm
#     <input type = "submit" value="YES">
#     <a href='/data'>Cancel</a>
# </form>
# Out:
# Writing delete.html

# %%
# %%file notfound.html
# <html>
# <head><title>Funding Analyzer</title></head>
# <body>
#     <h1> Row : {{ id }} not found . </h1>
# </body>
# </html>
# Out:
# Writing notfound.html

# %%
# %%file edit.html
# {% block content %}
# <h1 style="width: 100%">
#     {% block title %} Update a record {% endblock %}
# </h1>
#
# <form method="POST">
#             <p>
#             <label for="permalink">permalink</label>
#             <input type="text" name="permalink"
#                    value={{ s.permalink }}
#                    placeholder="permalink">
#             </input>
#             </p>
#
#             <p>
#             <label for="company">company</label>
#             <input type="text" name="company"
#                    value={{ s.company }}
#                    placeholder="company">
#             </input>
#             </p>
#
#             <p>
#             <label for="numEmps">numEmps</label>
#             <input type="number" name="numEmps"
#                    value={{ s.numEmps }}
#                    placeholder="numEmps">
#             </input>
#             </p>
#
#             <p>
#             <label for="category">category</label>
#             <input type="text" name="category"
#                    value={{ s.category }}
#                    placeholder="category">
#             </input>
#             </p>
#
#             <p>
#             <label for="city">city</label>
#             <input type="text" name="city"
#                    value={{ s.city }}
#                    placeholder="city">
#             </input>
#             </p>
#
#             <p>
#             <label for="state">state</label>
#             <input type="text" name="state"
#                    value={{ s.state }}
#                    placeholder="state">
#             </input>
#             </p>
#
#
#             <p>
#             <label for="fundedDate">fundedDate</label>
#             <input type="date" name="fundedDate"
#                    value={{ s.fundedDate }}
#                    placeholder="fundedDate">
#             </input>
#             </p>
#
#
#             <p>
#             <label for="raisedAmt">raisedAmt</label>
#             <input type="number" name="raisedAmt"
#                    value={{ s.raisedAmt }}
#                    placeholder="raisedAmt">
#             </input>
#             </p>
#
#             <p>
#             <label for="raisedCurrency">raisedCurrency</label>
#             <input type="text" name="raisedCurrency"
#                     value={{ s.raisedCurrency }}
#                    placeholder="raisedCurrency">
#             </input>
#             </p>
#
#             <p>
#             <label for="roundx">roundx</label>
#             <input type="text" name="roundx"
#                    value={{ s.roundx }}
#                    placeholder="roundx">
#             </input>
#             </p>
#
#              <p>
#              <button type="submit">Submit</button>
#              </p>
#     </form>
# {% endblock %}
# Out:
# Overwriting edit.html
